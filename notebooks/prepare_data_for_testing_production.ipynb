# %%
import pandas as pd
import numpy as np
import os

# %%
data_dir = '../data/feature_extraction/medianMinusPlus/'

# %%
df_raw = pd.read_csv(os.path.join(data_dir, 'raw.csv'), index_col=0)

# %%
df_pheno = pd.read_csv(os.path.join(data_dir,'updated_pheno.csv'), index_col=0)

# %%
df_meta = df_pheno[['subj_id','AGE_AT_SCAN ', 'SEX', 'SRS_TOTAL_T','SRS_AWARENESS_T',
                    'SRS_COGNITION_T','SRS_COMMUNICATION_T','SRS_MOTIVATION_T','SRS_MANNERISMS_T']]

# %%
df_meta.set_index('subj_id', inplace=True)

# %%
df_raw
# Out:
#                 area_lbankssts_medM2080  area_lbankssts_medP2080  \
# UCD_1_30004                    0.204148                 1.193672
# UCD_1_30012                    0.164031                 1.207366
# GU_1_28847                     0.121111                 1.341748
# UCD_1_30006                    0.147943                 1.192363
# KKI_29309                      0.212637                 1.231302
# ...                                 ...                      ...
# KKI_29374                      0.171225                 1.336328
# KKI_29455                      0.190822                 1.303782
# OHSU_1_28958                   0.228803                 1.199551
# SDSU_1_28868                   0.186721                 1.255179
# STANFORD_30195                 0.210175                 1.198460
#
#                 area_lcaudalanteriorcingulate_medM2080  \
# UCD_1_30004                                   0.037940
# UCD_1_30012                                   0.078433
# GU_1_28847                                    0.089056
# UCD_1_30006                                   0.107478
# KKI_29309                                     0.106183
# ...                                                ...
# KKI_29374                                     0.144533
# KKI_29455                                     0.174991
# OHSU_1_28958                                  0.147181
# SDSU_1_28868                                  0.082039
# STANFORD_30195                                0.118437
#
#                 area_lcaudalanteriorcingulate_medP2080  \
# UCD_1_30004                                   1.241528
# UCD_1_30012                                   1.253596
# GU_1_28847                                    1.238854
# UCD_1_30006                                   1.187279
# KKI_29309                                     1.168948
# ...                                                ...
# KKI_29374                                     1.301544
# KKI_29455                                     1.198766
# OHSU_1_28958                                  1.159829
# SDSU_1_28868                                  1.226956
# STANFORD_30195                                1.207716
#
#                 area_lcaudalmiddlefrontal_medM2080  \
# UCD_1_30004                               0.146131
# UCD_1_30012                               0.149466
# GU_1_28847                                0.155672
# UCD_1_30006                               0.114678
# KKI_29309                                 0.146371
# ...                                            ...
# KKI_29374                                 0.114157
# KKI_29455                                 0.131145
# OHSU_1_28958                              0.155679
# SDSU_1_28868                              0.098870
# STANFORD_30195                            0.141856
#
#                 area_lcaudalmiddlefrontal_medP2080  area_lcuneus_medM2080  \
# UCD_1_30004                               1.136687               0.031087
# UCD_1_30012                               1.175216              -0.028491
# GU_1_28847                                1.218820               0.041133
# UCD_1_30006                               1.222094               0.014594
# KKI_29309                                 1.306073               0.033239
# ...                                            ...                    ...
# KKI_29374                                 1.262241               0.022182
# KKI_29455                                 1.300666               0.111587
# OHSU_1_28958                              1.175983               0.051397
# SDSU_1_28868                              1.277283               0.014588
# STANFORD_30195                            1.212785               0.110179
#
#                 area_lcuneus_medP2080  area_lentorhinal_medM2080  \
# UCD_1_30004                  1.147981                   0.007735
# UCD_1_30012                  1.065152                   0.046511
# GU_1_28847                   1.173557                   0.151192
# UCD_1_30006                  1.151956                   0.053555
# KKI_29309                    1.338010                   0.172622
# ...                               ...                        ...
# KKI_29374                    1.361684                   0.142110
# KKI_29455                    1.305696                   0.141303
# OHSU_1_28958                 1.185879                   0.110073
# SDSU_1_28868                 1.298586                   0.157979
# STANFORD_30195               1.269298                   0.095829
#
#                 area_lentorhinal_medP2080  ...  \
# UCD_1_30004                      1.401248  ...
# UCD_1_30012                      1.237604  ...
# GU_1_28847                       1.167485  ...
# UCD_1_30006                      1.235169  ...
# KKI_29309                        1.121215  ...
# ...                                   ...  ...
# KKI_29374                        1.291797  ...
# KKI_29455                        1.288160  ...
# OHSU_1_28958                     1.235614  ...
# SDSU_1_28868                     1.115994  ...
# STANFORD_30195                   1.311371  ...
#
#                 volume_rsuperiortemporal_medP2080  \
# UCD_1_30004                              3.951214
# UCD_1_30012                              3.873525
# GU_1_28847                               4.493130
# UCD_1_30006                              4.149864
# KKI_29309                                4.327905
# ...                                           ...
# KKI_29374                                4.595162
# KKI_29455                                4.588392
# OHSU_1_28958                             4.407034
# SDSU_1_28868                             4.185168
# STANFORD_30195                           4.054904
#
#                 volume_rsupramarginal_medM2080  \
# UCD_1_30004                          -0.331369
# UCD_1_30012                          -0.429261
# GU_1_28847                           -0.486731
# UCD_1_30006                          -0.408154
# KKI_29309                            -0.721254
# ...                                        ...
# KKI_29374                            -0.656450
# KKI_29455                            -0.328011
# OHSU_1_28958                         -0.254569
# SDSU_1_28868                         -0.703994
# STANFORD_30195                       -0.629454
#
#                 volume_rsupramarginal_medP2080  volume_rtemporalpole_medM2080  \
# UCD_1_30004                           3.858788                      -0.333383
# UCD_1_30012                           3.629526                      -1.901276
# GU_1_28847                            4.216885                      -1.044621
# UCD_1_30006                           3.903106                      -1.245376
# KKI_29309                             4.049273                      -0.865518
# ...                                        ...                            ...
# KKI_29374                             3.806766                      -1.419426
# KKI_29455                             3.982458                      -2.386664
# OHSU_1_28958                          3.917674                      -0.700387
# SDSU_1_28868                          3.991835                      -0.963219
# STANFORD_30195                        3.933723                      -0.662729
#
#                 volume_rtemporalpole_medP2080  \
# UCD_1_30004                          7.158786
# UCD_1_30012                          6.009929
# GU_1_28847                           8.221329
# UCD_1_30006                          5.099309
# KKI_29309                            7.518871
# ...                                       ...
# KKI_29374                            5.887788
# KKI_29455                            7.434086
# OHSU_1_28958                         6.197593
# SDSU_1_28868                         7.340899
# STANFORD_30195                       9.025373
#
#                 volume_rtransversetemporal_medM2080  \
# UCD_1_30004                               -0.154218
# UCD_1_30012                               -0.285759
# GU_1_28847                                 0.312932
# UCD_1_30006                               -0.444463
# KKI_29309                                  0.062156
# ...                                             ...
# KKI_29374                                 -0.162324
# KKI_29455                                 -0.117385
# OHSU_1_28958                              -0.044168
# SDSU_1_28868                              -0.008321
# STANFORD_30195                             0.208626
#
#                 volume_rtransversetemporal_medP2080  DX_GROUP  AGE_AT_SCAN   \
# UCD_1_30004                                3.235628         2     16.333333
# UCD_1_30012                                3.236468         2     15.416667
# GU_1_28847                                 2.756782         2     10.490000
# UCD_1_30006                                3.230926         2     13.916667
# KKI_29309                                  3.653412         2      9.057534
# ...                                             ...       ...           ...
# KKI_29374                                  3.015415         2     11.024658
# KKI_29455                                  4.863548         2     11.528767
# OHSU_1_28958                               3.502964         1     12.000000
# SDSU_1_28868                               3.777410         2      8.700000
# STANFORD_30195                             3.239166         2     13.191600
#
#                 SEX
# UCD_1_30004       1
# UCD_1_30012       1
# GU_1_28847        1
# UCD_1_30006       2
# KKI_29309         2
# ...             ...
# KKI_29374         1
# KKI_29455         1
# OHSU_1_28958      1
# SDSU_1_28868      1
# STANFORD_30195    1
#
# [1038 rows x 547 columns]

# %%
df = df_raw.drop(['SEX','AGE_AT_SCAN '], axis=1).join(df_meta)

# %%
df.head()
# Out:
#              area_lbankssts_medM2080  area_lbankssts_medP2080  \
# UCD_1_30004                 0.204148                 1.193672
# UCD_1_30012                 0.164031                 1.207366
# GU_1_28847                  0.121111                 1.341748
# UCD_1_30006                 0.147943                 1.192363
# KKI_29309                   0.212637                 1.231302
#
#              area_lcaudalanteriorcingulate_medM2080  \
# UCD_1_30004                                0.037940
# UCD_1_30012                                0.078433
# GU_1_28847                                 0.089056
# UCD_1_30006                                0.107478
# KKI_29309                                  0.106183
#
#              area_lcaudalanteriorcingulate_medP2080  \
# UCD_1_30004                                1.241528
# UCD_1_30012                                1.253596
# GU_1_28847                                 1.238854
# UCD_1_30006                                1.187279
# KKI_29309                                  1.168948
#
#              area_lcaudalmiddlefrontal_medM2080  \
# UCD_1_30004                            0.146131
# UCD_1_30012                            0.149466
# GU_1_28847                             0.155672
# UCD_1_30006                            0.114678
# KKI_29309                              0.146371
#
#              area_lcaudalmiddlefrontal_medP2080  area_lcuneus_medM2080  \
# UCD_1_30004                            1.136687               0.031087
# UCD_1_30012                            1.175216              -0.028491
# GU_1_28847                             1.218820               0.041133
# UCD_1_30006                            1.222094               0.014594
# KKI_29309                              1.306073               0.033239
#
#              area_lcuneus_medP2080  area_lentorhinal_medM2080  \
# UCD_1_30004               1.147981                   0.007735
# UCD_1_30012               1.065152                   0.046511
# GU_1_28847                1.173557                   0.151192
# UCD_1_30006               1.151956                   0.053555
# KKI_29309                 1.338010                   0.172622
#
#              area_lentorhinal_medP2080  ...  \
# UCD_1_30004                   1.401248  ...
# UCD_1_30012                   1.237604  ...
# GU_1_28847                    1.167485  ...
# UCD_1_30006                   1.235169  ...
# KKI_29309                     1.121215  ...
#
#              volume_rtransversetemporal_medP2080  DX_GROUP  AGE_AT_SCAN   SEX  \
# UCD_1_30004                             3.235628         2     16.333333    1
# UCD_1_30012                             3.236468         2     15.416667    1
# GU_1_28847                              2.756782         2     10.490000    1
# UCD_1_30006                             3.230926         2     13.916667    2
# KKI_29309                               3.653412         2      9.057534    2
#
#              SRS_TOTAL_T  SRS_AWARENESS_T  SRS_COGNITION_T  \
# UCD_1_30004         40.0             35.0             42.0
# UCD_1_30012         39.0             38.0             40.0
# GU_1_28847          40.0             49.0             41.0
# UCD_1_30006         39.0             37.0             39.0
# KKI_29309           38.0             30.0             40.0
#
#              SRS_COMMUNICATION_T  SRS_MOTIVATION_T  SRS_MANNERISMS_T
# UCD_1_30004                 41.0              42.0              43.0
# UCD_1_30012                 40.0              38.0              43.0
# GU_1_28847                  37.0              40.0              44.0
# UCD_1_30006                 43.0              38.0              42.0
# KKI_29309                   41.0              38.0              44.0
#
# [5 rows x 553 columns]

# %%
SRS_SCORES_MAP = {
    'TD': (0, 59),
    'mild':(60, 65),
    'moderate':(66, 75),
    'sever':(76, 1000)
}

# %%
def add_severity_label_withnans(row, srs_type):
    if np.isnan(row[srs_type]):
        return 'sever' if row['DX_GROUP']==1 else 'TD'
    elif row[srs_type]<=59:
        return 'TD'
    elif row[srs_type] <= 65:
        return 'mild'
    elif row[srs_type] <= 75:
        return 'moderate'
    else:
        return 'sever'

# %%
df['severity_label_comm'] = df.apply(lambda x: add_severity_label_withnans(x, 'SRS_COMMUNICATION_T'), axis=1)
df['severity_label_awa'] = df.apply(lambda x: add_severity_label_withnans(x, 'SRS_AWARENESS_T'), axis=1)
df['severity_label_cog'] = df.apply(lambda x: add_severity_label_withnans(x, 'SRS_COGNITION_T'), axis=1)
df['severity_label_mot'] = df.apply(lambda x: add_severity_label_withnans(x, 'SRS_MOTIVATION_T'), axis=1)
df['severity_label_tot'] = df.apply(lambda x: add_severity_label_withnans(x, 'SRS_TOTAL_T'), axis=1)
df['severity_label_man'] = df.apply(lambda x: add_severity_label_withnans(x, 'SRS_MANNERISMS_T'), axis=1)

# %%
df.to_csv('raw_data_for_production_testing.csv')

# %%
df_td = df[df['DX_GROUP']==2]
df_asd = df[df['DX_GROUP']==1]

# %%
print(df_asd['severity_label_cog'].value_counts(),
df_asd['severity_label_tot'].value_counts(),
df_asd['severity_label_comm'].value_counts(),
df_asd['severity_label_man'].value_counts(),
df_asd['severity_label_mot'].value_counts(),
df_asd['severity_label_awa'].value_counts())
# Out:
# sever       292
# moderate     97
# TD           57
# mild         50
# Name: severity_label_cog, dtype: int64 sever       325
# moderate     98
# TD           44
# mild         29
# Name: severity_label_tot, dtype: int64 sever       309
# moderate     99
# TD           46
# mild         42
# Name: severity_label_comm, dtype: int64 sever       332
# moderate     88
# TD           40
# mild         36
# Name: severity_label_man, dtype: int64 sever       259
# moderate    113
# TD           81
# mild         43
# Name: severity_label_mot, dtype: int64 sever       270
# moderate     92
# TD           75
# mild         59
# Name: severity_label_awa, dtype: int64

# %%
print(df_td['severity_label_cog'].value_counts(),
df_td['severity_label_tot'].value_counts(),
df_td['severity_label_comm'].value_counts(),
df_td['severity_label_man'].value_counts(),
df_td['severity_label_mot'].value_counts(),
df_td['severity_label_awa'].value_counts())
# Out:
# TD          531
# mild          7
# moderate      4
# Name: severity_label_cog, dtype: int64 TD          528
# mild          7
# moderate      5
# sever         2
# Name: severity_label_tot, dtype: int64 TD          530
# mild          8
# moderate      4
# Name: severity_label_comm, dtype: int64 TD          525
# mild         12
# moderate      5
# Name: severity_label_man, dtype: int64 TD          522
# mild         12
# moderate      8
# Name: severity_label_mot, dtype: int64 TD          516
# mild         15
# moderate     11
# Name: severity_label_awa, dtype: int64
