# %%
import pandas as pd
import dill
import numpy as np
import os
import json

# %%
model2test = "../models/20210815_213208_perc_ubuntu_comm"

# %%
Xselected_dir = os.path.join(model2test, "Xselected.p")
normalizer_dir = os.path.join(model2test, 'normalizer.p')
df_dir = os.path.join(model2test, "group_df_afterFixation.csv")

selected_feats_dir = os.path.join(model2test, "selected_feats.json")

# %%
df = pd.read_csv(df_dir, index_col=0)
df.head()
# Out:
#               area_lbankssts_PERC20  area_lbankssts_PERC40  \
# subj_id
# NYU_1_29195                0.445095               0.646300
# NYU_1_29194                0.442522               0.670958
# OHSU_1_28988               0.463323               0.652318
# KKI_29393                  0.385124               0.618416
# BNI_1_29015                0.429934               0.656187
#
#               area_lbankssts_PERC60  area_lbankssts_PERC80  \
# subj_id
# NYU_1_29195                0.777230               0.926085
# NYU_1_29194                0.806857               0.949495
# OHSU_1_28988               0.794378               0.925766
# KKI_29393                  0.769144               0.942048
# BNI_1_29015                0.817121               0.988737
#
#               area_lcaudalanteriorcingulate_PERC20  \
# subj_id
# NYU_1_29195                               0.361371
# NYU_1_29194                               0.340219
# OHSU_1_28988                              0.415935
# KKI_29393                                 0.361135
# BNI_1_29015                               0.329007
#
#               area_lcaudalanteriorcingulate_PERC40  \
# subj_id
# NYU_1_29195                               0.600169
# NYU_1_29194                               0.562820
# OHSU_1_28988                              0.589041
# KKI_29393                                 0.561817
# BNI_1_29015                               0.554825
#
#               area_lcaudalanteriorcingulate_PERC60  \
# subj_id
# NYU_1_29195                               0.809482
# NYU_1_29194                               0.736010
# OHSU_1_28988                              0.740710
# KKI_29393                                 0.747379
# BNI_1_29015                               0.728816
#
#               area_lcaudalanteriorcingulate_PERC80  \
# subj_id
# NYU_1_29195                               0.993547
# NYU_1_29194                               0.894967
# OHSU_1_28988                              0.888398
# KKI_29393                                 0.926544
# BNI_1_29015                               0.849511
#
#               area_lcaudalmiddlefrontal_PERC20  \
# subj_id
# NYU_1_29195                           0.421400
# NYU_1_29194                           0.422197
# OHSU_1_28988                          0.368312
# KKI_29393                             0.393800
# BNI_1_29015                           0.383495
#
#               area_lcaudalmiddlefrontal_PERC40  ...  \
# subj_id                                         ...
# NYU_1_29195                           0.612405  ...
# NYU_1_29194                           0.620782  ...
# OHSU_1_28988                          0.562944  ...
# KKI_29393                             0.624207  ...
# BNI_1_29015                           0.586011  ...
#
#               volume_rtransversetemporal_PERC20  \
# subj_id
# NYU_1_29195                            0.904411
# NYU_1_29194                            0.918442
# OHSU_1_28988                           0.756564
# KKI_29393                              1.070782
# BNI_1_29015                            0.701568
#
#               volume_rtransversetemporal_PERC40  \
# subj_id
# NYU_1_29195                            1.562802
# NYU_1_29194                            1.567751
# OHSU_1_28988                           1.322274
# KKI_29393                              1.646824
# BNI_1_29015                            1.071326
#
#               volume_rtransversetemporal_PERC60  \
# subj_id
# NYU_1_29195                            2.259661
# NYU_1_29194                            2.305911
# OHSU_1_28988                           1.800495
# KKI_29393                              2.246192
# BNI_1_29015                            1.378491
#
#               volume_rtransversetemporal_PERC80  DX_GROUP  AGE_AT_SCAN   SEX  \
# subj_id
# NYU_1_29195                            3.506616         1      7.190000    1
# NYU_1_29194                            3.050552         1      5.920000    1
# OHSU_1_28988                           2.417393         1     11.000000    2
# KKI_29393                              3.028104         1     10.786301    1
# BNI_1_29015                            1.812680         1     47.000000    1
#
#               SRS_COMMUNICATION_T  categories_COMMUNICATION  my_labels
# subj_id
# NYU_1_29195                  94.0                     sever          1
# NYU_1_29194                  76.0                     sever          1
# OHSU_1_28988                 78.0                     sever          1
# KKI_29393                    90.0                     sever          1
# BNI_1_29015                  77.0                     sever          1
#
# [5 rows x 1094 columns]

# %%
with open(selected_feats_dir, 'r') as f:
    selected_feats = json.load(f)

# %%
with open(Xselected_dir, 'rb') as f:
    Xselected = dill.load(f)

# %%
with open(normalizer_dir, 'rb') as f:
    normalizer = dill.load(f)

# %%
Xselected[0].keys()
# Out:
# dict_keys(['lsvm', 'lr', 'xgb', 'rf'])

# %%
(Xselected[1] == df['my_labels'].values).sum()/len(Xselected[1])
# Out:
# 0.4819277108433735

# %%
selected_feats.keys()
# Out:
# dict_keys(['lsvm', 'lr', 'xgb', 'rf'])

# %%
len(selected_feats['lsvm']), Xselected[0]['lsvm'].shape[1]
# Out:
# (21, 21)

# %%
df_lsvm = df[selected_feats['lsvm']]

# %%
df_lsvm, Xselected[0]['lsvm']
# Out:
# (              area_listhmuscingulate_PERC40  area_llateraloccipital_PERC80  \
#  subj_id
#  NYU_1_29195                        0.522797                       1.002703
#  NYU_1_29194                        0.571181                       0.951581
#  OHSU_1_28988                       0.505649                       0.912174
#  KKI_29393                          0.580646                       0.978579
#  BNI_1_29015                        0.576045                       0.943476
#  ...                                     ...                            ...
#  KKI_29469                          0.556491                       0.954565
#  SDSU_1_28892                       0.530637                       0.855273
#  KKI_29474                          0.543721                       0.939510
#  KKI_29414                          0.552559                       0.943287
#  KKI_29310                          0.538254                       0.973771
#
#                area_lsuperiorparietal_PERC80  area_ltransversetemporal_PERC80  \
#  subj_id
#  NYU_1_29195                        0.971391                         0.949892
#  NYU_1_29194                        0.933320                         0.909737
#  OHSU_1_28988                       0.925658                         0.877937
#  KKI_29393                          0.960544                         0.922880
#  BNI_1_29015                        0.932727                         0.872409
#  ...                                     ...                              ...
#  KKI_29469                          0.947808                         0.915390
#  SDSU_1_28892                       0.898944                         0.839901
#  KKI_29474                          0.955380                         0.922711
#  KKI_29414                          0.965689                         0.952909
#  KKI_29310                          0.946865                         0.926113
#
#                area_rentorhinal_PERC20  area_risthmuscingulate_PERC20  \
#  subj_id
#  NYU_1_29195                  0.402292                       0.341591
#  NYU_1_29194                  0.454174                       0.325699
#  OHSU_1_28988                 0.279897                       0.341595
#  KKI_29393                    0.347979                       0.339919
#  BNI_1_29015                  0.423864                       0.336913
#  ...                               ...                            ...
#  KKI_29469                    0.365933                       0.380169
#  SDSU_1_28892                 0.439616                       0.322264
#  KKI_29474                    0.368915                       0.403215
#  KKI_29414                    0.404529                       0.372595
#  KKI_29310                    0.373990                       0.359217
#
#                area_rlateraloccipital_PERC80  area_rlingual_PERC40  \
#  subj_id
#  NYU_1_29195                        0.971014              0.639449
#  NYU_1_29194                        0.983030              0.588823
#  OHSU_1_28988                       0.912567              0.567460
#  KKI_29393                          0.970247              0.616937
#  BNI_1_29015                        0.937418              0.598526
#  ...                                     ...                   ...
#  KKI_29469                          0.967049              0.631286
#  SDSU_1_28892                       0.896524              0.542823
#  KKI_29474                          0.940526              0.603389
#  KKI_29414                          0.979111              0.638761
#  KKI_29310                          0.949155              0.601000
#
#                area_rparahippocampal_PERC20  area_rsuperiortemporal_PERC80  \
#  subj_id
#  NYU_1_29195                       0.428321                       0.949425
#  NYU_1_29194                       0.336304                       0.928503
#  OHSU_1_28988                      0.372937                       0.934375
#  KKI_29393                         0.368603                       0.960628
#  BNI_1_29015                       0.365447                       0.923696
#  ...                                    ...                            ...
#  KKI_29469                         0.434956                       0.989986
#  SDSU_1_28892                      0.393428                       0.924901
#  KKI_29474                         0.456573                       0.906949
#  KKI_29414                         0.394100                       0.991656
#  KKI_29310                         0.398721                       0.906306
#
#                ...  curv_llingual_PERC40  curv_lprecentral_PERC80  \
#  subj_id       ...
#  NYU_1_29195   ...             -0.081691                 0.132604
#  NYU_1_29194   ...             -0.079519                 0.140388
#  OHSU_1_28988  ...             -0.112714                 0.141854
#  KKI_29393     ...             -0.101629                 0.138568
#  BNI_1_29015   ...             -0.101935                 0.124485
#  ...           ...                   ...                      ...
#  KKI_29469     ...             -0.097700                 0.136409
#  SDSU_1_28892  ...             -0.100354                 0.123463
#  KKI_29474     ...             -0.128359                 0.142836
#  KKI_29414     ...             -0.058958                 0.137119
#  KKI_29310     ...             -0.086742                 0.126078
#
#                thickness_lfrontalpole_PERC40  thickness_linsula_PERC60  \
#  subj_id
#  NYU_1_29195                        3.195665                  2.004331
#  NYU_1_29194                        3.004971                  2.025336
#  OHSU_1_28988                       3.106212                  2.192970
#  KKI_29393                          2.494899                  2.185066
#  BNI_1_29015                        2.635773                  1.761079
#  ...                                     ...                       ...
#  KKI_29469                          3.412998                  2.194365
#  SDSU_1_28892                       2.822888                  2.046894
#  KKI_29474                          3.059204                  1.813728
#  KKI_29414                          2.042779                  2.304900
#  KKI_29310                          3.616766                  2.376959
#
#                thickness_lsupramarginal_PERC60  \
#  subj_id
#  NYU_1_29195                          3.051846
#  NYU_1_29194                          3.040173
#  OHSU_1_28988                         3.038515
#  KKI_29393                            2.591305
#  BNI_1_29015                          2.384150
#  ...                                       ...
#  KKI_29469                            3.001854
#  SDSU_1_28892                         2.727859
#  KKI_29474                            2.887953
#  KKI_29414                            2.883297
#  KKI_29310                            3.065348
#
#                thickness_rsuperiortemporal_PERC80  \
#  subj_id
#  NYU_1_29195                             3.702331
#  NYU_1_29194                             3.774999
#  OHSU_1_28988                            3.516987
#  KKI_29393                               3.737462
#  BNI_1_29015                             3.311212
#  ...                                          ...
#  KKI_29469                               3.641755
#  SDSU_1_28892                            3.162899
#  KKI_29474                               3.655803
#  KKI_29414                               3.822261
#  KKI_29310                               3.925040
#
#                thickness_rsupramarginal_PERC40  volume_rparahippocampal_PERC80  \
#  subj_id
#  NYU_1_29195                          2.678706                        2.972995
#  NYU_1_29194                          2.771626                        2.595008
#  OHSU_1_28988                         2.870279                        3.238262
#  KKI_29393                            2.365230                        2.807050
#  BNI_1_29015                          2.225166                        2.742823
#  ...                                       ...                             ...
#  KKI_29469                            2.591419                        3.113780
#  SDSU_1_28892                         2.320263                        3.519571
#  KKI_29474                            2.570883                        3.327852
#  KKI_29414                            2.411732                        3.027206
#  KKI_29310                            2.921436                        3.797331
#
#                volume_rparstriangularis_PERC40  volume_rpericalcarine_PERC60
#  subj_id
#  NYU_1_29195                          1.600896                      1.308169
#  NYU_1_29194                          1.739552                      1.407977
#  OHSU_1_28988                         1.497533                      1.093974
#  KKI_29393                            1.457328                      1.417228
#  BNI_1_29015                          1.310013                      0.883186
#  ...                                       ...                           ...
#  KKI_29469                            1.631675                      1.290777
#  SDSU_1_28892                         1.369048                      1.103550
#  KKI_29474                            1.693376                      1.235172
#  KKI_29414                            1.579982                      1.295745
#  KKI_29310                            1.841782                      1.551110
#
#  [332 rows x 21 columns],
#  array([[ -21.55176874,  -30.46848699,  -37.31244597, ...,  -11.18858949,
#           -45.34223389,  -12.52319718],
#         [ -33.07039843,  -84.34886658, -108.14142115, ...,   -7.21477501,
#           -24.55761076,  -11.52111858],
#         [ -29.98875806,   12.1348419 ,   64.75524044, ...,   -6.43432895,
#             4.96722298,   -5.70861015],
#         ...,
#         [ -65.4044823 ,  -14.05861793,  -24.8297201 , ...,   -8.68955507,
#           -10.90098522,   -1.89862239],
#         [   2.84347245,   23.98817423,  -14.97942852, ...,   -7.55950517,
#           -18.88512174,   -6.50762883],
#         [  15.75138669,  -31.86848154,  -21.76846786, ...,   -7.17608207,
#           -13.84199808,   -9.70198299]]))
