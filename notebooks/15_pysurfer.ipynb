# %% [markdown]
# # pysurfer

# %%
# Links
"http://pysurfer.github.io/generated/surfer.Brain.html#surfer.Brain"
"https://docs.enthought.com/mayavi/mayavi/auto/mlab_camera.html#mayavi.mlab.view" # Usefull when use brain.show_view

# %%
from mayavi import mlab
mlab.init_notebook(backend='png')
import os
import numpy as np
import matplotlib.pyplot as plt
from mayavi import mlab
from tvtk.api import tvtk
from tvtk.common import configure_input_data
from surfer import Brain
# Out:
# Notebook initialized with png backend.

# %%
# Set subjectsidr env path
os.environ['SUBJECTS_DIR']="/media/tarek/D/Autism/Structural_MRI/AbideII_FreeSurfer"

# %%
sub_path = os.environ.get("FREESURFER_SUBJECTS")

# %%
subj_id = os.listdir(sub_path)[0]

# %%
surf_dir = os.path.join(sub_path, subj_sample, 'surf')
surf_dir = os.path.join(sub_path, subj_sample, 'surf')

# %%
brain = Brain(subject_id = subj_id, hemi='lh', surf='inflated', cortex='high_contrast', views=['lat', 'medial'])

# %%
brain
# Out:
# <img src="data:image/png;base64,..." alt="PNG image"></img>
# <img src="data:image/png;base64,..." alt="PNG image"></img>
